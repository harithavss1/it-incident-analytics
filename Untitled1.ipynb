# %%
import subprocess
subprocess.run(['pip', 'install', 'pandas', 'numpy', 'matplotlib', 'seaborn'])
# Out:
# CompletedProcess(args=['pip', 'install', 'pandas', 'numpy', 'matplotlib', 'seaborn'], returncode=0)
